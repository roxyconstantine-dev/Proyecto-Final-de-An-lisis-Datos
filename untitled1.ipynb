# %% [markdown]
# <a href="https://colab.research.google.com/github/roxyconstantine-dev/Proyecto-Final-de-An-lisis-Datos/blob/main/untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Proyecto final de Posgrado de Analisis de Datos con Python
#
# En el siguente proyecto se realiza en analisis de datos concretos de muestras de laboratorio de la industria minera realizados por el CIMPPIN.

# %%
import pandas as pd
import numpy as np

from sklearn.decomposition import FactorAnalysis, PCA
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import train_test_split, RandomizedSearchCV, learning_curve

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.cluster import KMeans
import math
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import uniform
import statistics as stats





   # print(data.iloc[i]['first_name'])
   #for column in [data.isnull().any(axis=1)==True] : #Recorrer las columnas e interactura solo sobre las que tiene elementos nulos
     
    # for index in range(df.shape[1]):
    
     #   return lista

# %%
import pandas as pd
url="https://github.com/roxyconstantine-dev/Proyecto-Final-de-An-lisis-Datos/blob/main/ParaRosana.xlsx?raw=true"
datos=pd.read_excel(url)
#datos=datos.drop("Frente:")
datos
# Out:
#        Ni     Co     Fe   SiO2   MgO  Al2O3  Cr2O3    Mn    Cu    Zn    Na  \
# 0    1.23  0.130  42.01   8.46  2.98   4.85   2.00  1.00  0.02  0.03  0.21
# 1    0.93  0.050  41.59   4.05  0.52   6.05   1.46  0.36  0.02  0.02  0.22
# 2    1.10  0.070  44.80   5.87  0.40  14.41   1.35  0.55  0.02  0.02  0.22
# 3    1.14  0.080  43.96   5.12  0.96   8.09   1.25  0.57  0.02  0.02  0.22
# 4    1.11  0.090  43.98   4.85  0.40   9.99   1.30  0.64  0.02  0.02  0.15
# ..    ...    ...    ...    ...   ...    ...    ...   ...   ...   ...   ...
# 410  1.58  0.104  26.91  23.36  8.03   2.59   1.22  0.47   NaN   NaN   NaN
# 411  1.41  0.184  44.37   6.66  1.46   6.23   1.97  0.85   NaN   NaN   NaN
# 412  1.19  0.151  41.96   6.96  1.64   5.03   1.98  0.71   NaN   NaN   NaN
# 413  1.32  0.074  28.71  21.43  7.19   2.71   1.27  0.57   NaN   NaN   NaN
# 414  1.31  0.169  42.99   7.65  1.20   7.63   1.95  1.01   NaN   NaN   NaN
#
#         K
# 0    0.01
# 1    0.01
# 2    0.01
# 3    0.00
# 4    0.01
# ..    ...
# 410   NaN
# 411   NaN
# 412   NaN
# 413   NaN
# 414   NaN
#
# [415 rows x 12 columns]

# %% [markdown]
# Para conocer el numero de datos faltantes se ejecuta el siguiente codigo

# %%
datos.isnull().sum().sum()
# Out:
# 1103

# %% [markdown]
# Tenemos numerosos datos vacios.
# Calculemos los valores faltantes por columna.

# %%
datos2 = datos.fillna(0)
datos2
# Out:
#        Ni     Co     Fe   SiO2   MgO  Al2O3  Cr2O3    Mn    Cu    Zn    Na  \
# 0    1.23  0.130  42.01   8.46  2.98   4.85   2.00  1.00  0.02  0.03  0.21
# 1    0.93  0.050  41.59   4.05  0.52   6.05   1.46  0.36  0.02  0.02  0.22
# 2    1.10  0.070  44.80   5.87  0.40  14.41   1.35  0.55  0.02  0.02  0.22
# 3    1.14  0.080  43.96   5.12  0.96   8.09   1.25  0.57  0.02  0.02  0.22
# 4    1.11  0.090  43.98   4.85  0.40   9.99   1.30  0.64  0.02  0.02  0.15
# ..    ...    ...    ...    ...   ...    ...    ...   ...   ...   ...   ...
# 410  1.58  0.104  26.91  23.36  8.03   2.59   1.22  0.47  0.00  0.00  0.00
# 411  1.41  0.184  44.37   6.66  1.46   6.23   1.97  0.85  0.00  0.00  0.00
# 412  1.19  0.151  41.96   6.96  1.64   5.03   1.98  0.71  0.00  0.00  0.00
# 413  1.32  0.074  28.71  21.43  7.19   2.71   1.27  0.57  0.00  0.00  0.00
# 414  1.31  0.169  42.99   7.65  1.20   7.63   1.95  1.01  0.00  0.00  0.00
#
#         K
# 0    0.01
# 1    0.01
# 2    0.01
# 3    0.00
# 4    0.01
# ..    ...
# 410  0.00
# 411  0.00
# 412  0.00
# 413  0.00
# 414  0.00
#
# [415 rows x 12 columns]

# %% [markdown]
# Los valores de Cr2O3,Cu,Zn,Na,K exiben la mayor cantidad de valores nulos.Vamos a analizar su comportamiento para predecir ls valores de los que podrian tratarse esatas casillas nulas ya que eliminarlas nos haría perder mucha información.

# %%
datos2.describe()
# Out:
#                Ni          Co          Fe        SiO2         MgO       Al2O3  \
# count  415.000000  415.000000  415.000000  415.000000  415.000000  415.000000
# mean     1.065952    0.117424   39.940843    8.580795    3.453520    6.786699
# std      0.295700    0.057222    8.186679    7.226787    4.175502    2.403382
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.850000    0.080000   36.205000    3.440000    0.835000    5.270000
# 50%      1.050000    0.100000   42.460000    6.590000    1.730000    6.510000
# 75%      1.250000    0.150000   45.830000   11.025000    4.365000    8.075000
# max      2.000000    0.330000   50.300000   50.080000   21.960000   16.790000
#
#             Cr2O3          Mn          Cu          Zn          Na           K
# count  415.000000  415.000000  415.000000  415.000000  415.000000  415.000000
# mean     1.448289    0.743711    0.007325    0.014988    0.024916    0.000867
# std      1.106084    0.319766    0.009053    0.018056    0.042249    0.002818
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.550000    0.000000    0.000000    0.000000    0.000000
# 50%      1.580000    0.700000    0.000000    0.000000    0.000000    0.000000
# 75%      2.215000    0.880000    0.020000    0.030000    0.040000    0.000000
# max      4.710000    3.000000    0.040000    0.050000    0.220000    0.010000

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

datos2['Ni']=MinMaxScaler().fit_transform(np.array(datos2['Ni']).reshape(-1,1))
datos2['Fe']=MinMaxScaler().fit_transform(np.array(datos2['Fe']).reshape(-1,1))
datos2['SiO2']=MinMaxScaler().fit_transform(np.array(datos2['SiO2']).reshape(-1,1))
datos2['MgO']=MinMaxScaler().fit_transform(np.array(datos2['MgO']).reshape(-1,1))
datos2['Al2O3']=MinMaxScaler().fit_transform(np.array(datos2['Al2O3']).reshape(-1,1))
datos2['Cr2O3']=MinMaxScaler().fit_transform(np.array(datos2['Cr2O3']).reshape(-1,1))
datos2['MgO']=MinMaxScaler().fit_transform(np.array(datos2['MgO']).reshape(-1,1))
datos2['Mn']=MinMaxScaler().fit_transform(np.array(datos2['Mn']).reshape(-1,1))
datos2['Co']=MinMaxScaler().fit_transform(np.array(datos2['Co']).reshape(-1,1))
datos2['Cu']=MinMaxScaler().fit_transform(np.array(datos2['Cu']).reshape(-1,1))
datos2['K']=MinMaxScaler().fit_transform(np.array(datos2['K']).reshape(-1,1))
datos2['Na']=MinMaxScaler().fit_transform(np.array(datos2['Na']).reshape(-1,1))
datos2['Zn']=MinMaxScaler().fit_transform(np.array(datos2['Zn']).reshape(-1,1))

# %%
datos2.var()
# Out:
# Ni       0.021860
# Co       0.030067
# Fe       0.026490
# SiO2     0.020824
# MgO      0.036154
# Al2O3    0.020490
# Cr2O3    0.055149
# Mn       0.011361
# Cu       0.051224
# Zn       0.130411
# Na       0.036879
# K        0.079413
# dtype: float64

# %%
#NORMALIZANDO llevando a media cero y varianza 1
from scipy.ndimage import standard_deviation
arreglo=datos2.to_numpy()

from sklearn.preprocessing import StandardScaler
X=StandardScaler().fit_transform(arreglo)
A=pd.DataFrame(X)
print(A)

#
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.555448  0.220037  0.253052 -0.016735 -0.113541 -0.806795  0.499399
# 1   -0.460317 -1.179725  0.201687 -0.627701 -0.703403 -0.306896  0.010600
# 2    0.115283 -0.829785  0.594261 -0.375557 -0.732177  3.175734 -0.088970
# 3    0.250719 -0.654815  0.491531 -0.479462 -0.597899  0.542932 -0.179488
# 4    0.149142 -0.479844  0.493977 -0.516868 -0.732177  1.334439 -0.134229
# ..        ...       ...       ...       ...       ...       ...       ...
# 410  1.740508 -0.234886 -1.593634  2.047527  1.097354 -1.748271 -0.206643
# 411  1.164908  1.164876  0.541673 -0.266109 -0.478009 -0.231911  0.472243
# 412  0.420013  0.587474  0.246937 -0.224547 -0.434848 -0.731810  0.481295
# 413  0.860178 -0.759797 -1.373499  1.780143  0.895938 -1.698281 -0.161384
# 414  0.826319  0.902421  0.372903 -0.128953 -0.540352  0.351304  0.454140
#
#            7         8         9         10        11
# 0    0.802457  1.401725  0.832410  4.386112  3.244654
# 1   -1.201421  1.401725  0.277915  4.623091  3.244654
# 2   -0.606520  1.401725  0.277915  4.623091  3.244654
# 3   -0.543899  1.401725  0.277915  4.623091 -0.308199
# 4   -0.324725  1.401725  0.277915  2.964237  3.244654
# ..        ...       ...       ...       ...       ...
# 410 -0.857005 -0.810122 -0.831074 -0.590449 -0.308199
# 411  0.332798 -0.810122 -0.831074 -0.590449 -0.308199
# 412 -0.105551 -0.810122 -0.831074 -0.590449 -0.308199
# 413 -0.543899 -0.810122 -0.831074 -0.590449 -0.308199
# 414  0.833767 -0.810122 -0.831074 -0.590449 -0.308199
#
# [415 rows x 12 columns]

# %%
print(sum(X))
# Out:
# [ 1.25788269e-13 -1.53765889e-13 -3.13027382e-13 -3.01147995e-14
#  -1.94289029e-14 -3.20854454e-14  9.49240686e-14 -4.92939023e-14
#  -6.34159392e-13 -1.17239551e-13  4.25215418e-13  5.41455769e-13]

# %%
#Mostrando el grafioc de algunas muestras en funcion del Niquel que es el principal objeto de estudio
x=X[:,0]
y=X[:,1]
plt.figure(figsize=(15,10))
y1=X[:,2]
y2=X[:,3]
plt.plot(x, y,'.', label = "Niquel y Cobalto")
plt.plot(x, y1,'.', label = "Niquel y Hierro")
plt.plot(x, y2,'.', label = "Niquel y SiO2")
plt.legend(loc = "upper left")

# %%
#Mostrando el grafioc de algunas muestras en funcion del Niquel que es el principal objeto de estudio
x=X[:,0]
y=X[:,5]
plt.figure(figsize=(15,10))
y1=X[:,6]
y2=X[:,7]
plt.plot(x, y,'.', label = "Niquel y Oxido de Silicio",color="orange")
plt.plot(x, y1,'.', label = "Niquel y Oxido de Magnesio",color="red")
plt.plot(x, y2,'.', label = "Niquel y Oxido de Aluminio ",color="blue")
plt.legend(loc = "upper left")

# %%
#Mostrando el grafioc de algunas muestras en funcion del Niquel que es el principal objeto de estudio
x=X[:,0]
y=X[:,8]
plt.figure(figsize=(15,10))
y1=X[:,9]
y2=X[:,10]
plt.plot(x, y,'.', label = "Niquel y Oxido de Silicio",color="black")
plt.plot(x, y1,'.', label = "Niquel y Oxido de Magnesio",color="green")
plt.plot(x, y2,'.', label = "Niquel y Oxido de Aluminio ",color="violet")
plt.legend(loc = "upper left")

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=8)
CP=pca.fit_transform(X)
print(CP)
# Out:
# [[ 2.59409264  2.52756118  1.48736121 ...  1.73745488  1.70822937
#    0.36794786]
#  [ 2.02968385  2.34429799  3.86129025 ...  2.01984534  1.43914083
#   -0.05504232]
#  [ 2.9661481   1.39718503  4.59980802 ... -0.46583754  0.09435284
#   -0.07012087]
#  ...
#  [-0.89893392 -0.9612893  -0.84229294 ...  0.56626872  0.20839176
#    0.04790691]
#  [-2.58366292  1.83731444 -1.1123732  ...  0.20610396  0.28956594
#    0.25512696]
#  [-0.36036623 -1.41411681 -1.13903515 ... -0.28728468 -0.05503066
#    0.06714826]]

# %%
pca.components_
# Out:
# array([[-0.06670617,  0.32624276,  0.28664299, -0.22488764, -0.1962321 ,
#          0.18003516, -0.35479058,  0.23661506,  0.46209878,  0.45471953,
#          0.24764999,  0.14818537],
#        [ 0.16716356, -0.13705058, -0.36905243,  0.43105386,  0.43196152,
#         -0.24985584, -0.28276947, -0.17396763,  0.22424192,  0.24682625,
#          0.2950595 ,  0.27158168]])

# %% [markdown]
# Al notar los componentes no existen valores que esean extremadamente diferentes al resto, pero entre los mas diferentes serian la columna 3(Hierro Fe) y la columna 6 y 7 (Al2O3 y Cr2O3).Atendiendo a los criterios de los especialista se decidio mantener los valores de Hierro en la grafica a pesar de los valores dados en el PCA. Prescindiremos entonces de los valores de Al2O3 y Cr2O3.

# %%
datos2.corr()
# Out:
#              Ni        Co        Fe      SiO2       MgO     Al2O3     Cr2O3  \
# Ni     1.000000  0.082687 -0.150377  0.289728  0.253629 -0.290201  0.040845
# Co     0.082687  1.000000  0.350805 -0.306691 -0.229884  0.098564 -0.260931
# Fe    -0.150377  0.350805  1.000000 -0.648728 -0.656450  0.374012 -0.004406
# SiO2   0.289728 -0.306691 -0.648728  1.000000  0.698718 -0.385802 -0.081084
# MgO    0.253629 -0.229884 -0.656450  0.698718  1.000000 -0.456551 -0.203027
# Al2O3 -0.290201  0.098564  0.374012 -0.385802 -0.456551  1.000000  0.153300
# Cr2O3  0.040845 -0.260931 -0.004406 -0.081084 -0.203027  0.153300  1.000000
# Mn     0.144454  0.704713  0.294228 -0.252828 -0.230270  0.110149 -0.129637
# Cu    -0.033713  0.277951  0.208929 -0.090318 -0.028676  0.088448 -0.724406
# Zn     0.005427  0.334224  0.174738 -0.059198  0.049550  0.004922 -0.793204
# Na     0.020032 -0.043764 -0.094029  0.212706  0.066316  0.229369 -0.289073
# K      0.111544  0.023186 -0.157694  0.240220  0.131636  0.083020 -0.165362
#
#              Mn        Cu        Zn        Na         K
# Ni     0.144454 -0.033713  0.005427  0.020032  0.111544
# Co     0.704713  0.277951  0.334224 -0.043764  0.023186
# Fe     0.294228  0.208929  0.174738 -0.094029 -0.157694
# SiO2  -0.252828 -0.090318 -0.059198  0.212706  0.240220
# MgO   -0.230270 -0.028676  0.049550  0.066316  0.131636
# Al2O3  0.110149  0.088448  0.004922  0.229369  0.083020
# Cr2O3 -0.129637 -0.724406 -0.793204 -0.289073 -0.165362
# Mn     1.000000  0.106022  0.124091 -0.109949 -0.000259
# Cu     0.106022  1.000000  0.919657  0.552372  0.294223
# Zn     0.124091  0.919657  1.000000  0.487333  0.259829
# Na    -0.109949  0.552372  0.487333  1.000000  0.573846
# K     -0.000259  0.294223  0.259829  0.573846  1.000000

# %%
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import scale

pca_pipe = make_pipeline(StandardScaler(), PCA())
pca_pipe.fit(datos2)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('pca', PCA())])

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 7))
modelo_pca = pca_pipe.named_steps['pca']
componentes = modelo_pca.components_
plt.imshow(componentes.T, cmap='viridis', aspect='auto')
plt.yticks(range(len(datos.columns)), datos.columns)
plt.xticks(range(len(datos.columns)), np.arange(modelo_pca.n_components_) + 1)
plt.grid(False)
plt.colorbar();

# %%
print('----------------------------------------------------')
print('Porcentaje de varianza explicada por cada componente')
print('----------------------------------------------------')
print(modelo_pca.explained_variance_ratio_)
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6, 4))
ax.bar(
x = np.arange(modelo_pca.n_components_) + 1,
height = modelo_pca.explained_variance_ratio_
)
for x, y in zip(np.arange(len(datos.columns)) + 1, modelo_pca.explained_variance_ratio_):label = round(y, 2)
ax.annotate(
label,
(x,y),
textcoords="offset points",
xytext=(0,10),
ha='center'
)
ax.set_xticks(np.arange(modelo_pca.n_components_) + 1)
ax.set_ylim(0, 1.1)
ax.set_title('Porcentaje de varianza explicada por cada componente')
ax.set_xlabel('Componentes principales')
ax.set_ylabel('Por. varianza explicada');
# Out:
# ----------------------------------------------------
# Porcentaje de varianza explicada por cada componente
# ----------------------------------------------------
# [0.27725974 0.25503282 0.13782849 0.10198238 0.06324551 0.04419259
#  0.02903343 0.02730502 0.02409728 0.02006103 0.01441002 0.0055517 ]

# %% [markdown]
# La varianza en los datos relativos al K(potasio) en la grafica se observan practicamente despreciables.

# %%
df=datos2
scaler=StandardScaler()
scaler.fit(df) # calculo la media para poder hacer la transformacion
X_scaled=scaler.transform(df)# Ahora si, escalo los datos y los normalizo
scaler.fit(df) # calculo la media para poder hacer la transformacion
X_scaled=scaler.transform(df)# Ahora si, escalo los datos y los normalizo

# %%
#Instanciamos objeto PCA y aplicamos
pca=PCA(n_components=6) # Otra opción es instanciar pca sólo con dimensiones nuevas hasta obtener un mínimo "explicado" 
pca.fit(X_scaled) # obtener los componentes principales
X_pca=pca.transform(X_scaled) # convertimos nuestros datos con las nuevas dimensiones de PCA
print("shape of X_pca", X_pca.shape)
expl = pca.explained_variance_ratio_
print(expl)
print (pca.explained_variance_)
print (pca.explained_variance_ratio_)
print (pca.explained_variance_ratio_.cumsum())
print('suma:',sum(expl[0:6]))
# Out:
# shape of X_pca (415, 6)
# [0.27725974 0.25503282 0.13782849 0.10198238 0.06324551 0.04419259]
# [3.33515334 3.06778604 1.65793687 1.22674454 0.76077932 0.53159204]
# [0.27725974 0.25503282 0.13782849 0.10198238 0.06324551 0.04419259]
# [0.27725974 0.53229255 0.67012104 0.77210342 0.83534893 0.87954152]
# suma: 0.8795415163814118

# %%
#Graficamos el acumulado de varianza explicada en las nuevas dimensiones
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Número de componentes (dimensiones)')
plt.ylabel('Acumulación de la varianza')
plt.show()

# %% [markdown]
# Con solo 7 componentes se alcanza el 87,9 % de la varianza.

# %%
nuevos_datos3=datos2.iloc[:,0:7]
nuevos_datos3
# Out:
#         Ni        Co        Fe      SiO2       MgO     Al2O3     Cr2O3
# 0    0.615  0.393939  0.835189  0.168930  0.135701  0.288862  0.424628
# 1    0.465  0.151515  0.826839  0.080871  0.023679  0.360334  0.309979
# 2    0.550  0.212121  0.890656  0.117212  0.018215  0.858249  0.286624
# 3    0.570  0.242424  0.873956  0.102236  0.043716  0.481834  0.265393
# 4    0.555  0.272727  0.874354  0.096845  0.018215  0.594997  0.276008
# ..     ...       ...       ...       ...       ...       ...       ...
# 410  0.790  0.315152  0.534990  0.466454  0.365665  0.154258  0.259023
# 411  0.705  0.557576  0.882107  0.132987  0.066485  0.371054  0.418259
# 412  0.595  0.457576  0.834195  0.138978  0.074681  0.299583  0.420382
# 413  0.660  0.224242  0.570775  0.427915  0.327413  0.161406  0.269639
# 414  0.655  0.512121  0.854672  0.152756  0.054645  0.454437  0.414013
#
# [415 rows x 7 columns]

# %% [markdown]
# Con la nueva redimensionalidad de los datos procedemos a hacer los agrupamientos.

# %% [markdown]
# # **Clousters**

# %% [markdown]
# Determinar el numero de clusters

# %%
#Cargando el dataset
data = nuevos_datos3
data.head()
# Out:
#       Ni        Co        Fe      SiO2       MgO     Al2O3     Cr2O3
# 0  0.615  0.393939  0.835189  0.168930  0.135701  0.288862  0.424628
# 1  0.465  0.151515  0.826839  0.080871  0.023679  0.360334  0.309979
# 2  0.550  0.212121  0.890656  0.117212  0.018215  0.858249  0.286624
# 3  0.570  0.242424  0.873956  0.102236  0.043716  0.481834  0.265393
# 4  0.555  0.272727  0.874354  0.096845  0.018215  0.594997  0.276008

# %%
print("Número de filas: " + str(data.shape[0]))
print("Número de columnas: " + str(data.shape[1]),'\n')
print('Tipo de variables:','\n', data.dtypes)
# Out:
# Número de filas: 415
# Número de columnas: 7
#
# Tipo de variables:
#  Ni       float64
# Co       float64
# Fe       float64
# SiO2     float64
# MgO      float64
# Al2O3    float64
# Cr2O3    float64
# dtype: object

# %%
# Mostramos los nombres de variables originales
data.columns

# Renombrando las variables del DataFrame 
data.columns = ['Ni', 'Co', 'Fe', 'SiO2','MgO','Al203','Cr203']
data.columns
# Out:
# Index(['Ni', 'Co', 'Fe', 'SiO2', 'MgO', 'Al203', 'Cr203'], dtype='object')

# %%
# Se crean listas según el tipo de variable
string = []
numeric = ['Ni', 'Co', 'Fe', 'SiO2','MgO','Al203','Cr203']
data[numeric].describe()
# Out:
#                Ni          Co          Fe        SiO2         MgO       Al203  \
# count  415.000000  415.000000  415.000000  415.000000  415.000000  415.000000
# mean     0.532976    0.355831    0.794053    0.171342    0.157264    0.404211
# std      0.147850    0.173399    0.162757    0.144305    0.190141    0.143144
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.425000    0.242424    0.719781    0.068690    0.038024    0.313877
# 50%      0.525000    0.303030    0.844135    0.131589    0.078780    0.387731
# 75%      0.625000    0.454545    0.911133    0.220148    0.198770    0.480941
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#             Cr203
# count  415.000000
# mean     0.307492
# std      0.234837
# min      0.000000
# 25%      0.000000
# 50%      0.335456
# 75%      0.470276
# max      1.000000

# %%
data[numeric].hist(bins = 50, figsize=(20,15))
plt.show()

# %%
# Calculando el número de clúster adecuado:
scores = [KMeans(n_clusters=i).fit(X).inertia_ for i in range(1,400)]
plt.figure(figsize=(15,10))
sns.lineplot(np.arange(1,400), scores)
plt.xlabel('Numero de clusters')
plt.ylabel("Inercia")
plt.title("Inercia de k-Means versus número de clusters")

# %% [markdown]
# El grafico nos indica que deben ser a partir de 200 clusters hasta 414 que es el totoal de datos.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn import metrics
# Obtenemos los indicadores de clustering:
for i in range(200,400):
  kmeans = KMeans(n_clusters= i)
  kmeans.fit(X)
  cluster = kmeans.predict(X)
  print('cluster con',i,'segmentos')
  print('Inercia: '+str(kmeans.inertia_)) 
  print('Silueta euclidena: '+str(metrics.silhouette_score(X, cluster, metric='euclidean')))
  print('Silueta coseno: '+str(metrics.silhouette_score(X, cluster, metric='cosine')))
  print('\n')
# Out:
# cluster con 200 segmentos
# Inercia: 110.7900557690522
# Silueta: 0.2060121746022607
# Silueta: 0.2666089363660859
#
#
# cluster con 201 segmentos
# Inercia: 108.0727102727285
# Silueta: 0.19209661868141356
# Silueta: 0.23272206746202073
#
#
# cluster con 202 segmentos
# Inercia: 108.6693686261485
# Silueta: 0.18645366684662515
# Silueta: 0.23944476251987096
#
#
# cluster con 203 segmentos
# Inercia: 107.33671767523434
# Silueta: 0.19054950020697137
# Silueta: 0.2380103104306591
#
#
# cluster con 204 segmentos
# Inercia: 106.8996963742591
# Silueta: 0.18075647640915057
# Silueta: 0.22728769963345383
#
#
# cluster con 205 segmentos
# Inercia: 103.98172348924689
# Silueta: 0.19226745316953675
# Silueta: 0.23922842847261988
#
#
# cluster con 206 segmentos
# Inercia: 102.14901438009275
# Silueta: 0.18674916538526354
# Silueta: 0.23746790199188217
#
#
# cluster con 207 segmentos
# Inercia: 100.14933101448436
# Silueta: 0.19135743629879887
# Silueta: 0.2425481952839934
#
#
# cluster con 208 segmentos
# Inercia: 100.34994318088353
# Silueta: 0.18839236347659255
# Silueta: 0.24029886653860164
#
#
# cluster con 209 segmentos
# Inercia: 97.41103286890056
# Silueta: 0.18944003782238134
# Silueta: 0.25135408620981553
#
#
# cluster con 210 segmentos
# Inercia: 97.3954128393533
# Silueta: 0.19228364175249407
# Silueta: 0.2456032277384984
#
#
# cluster con 211 segmentos
# Inercia: 96.85015224642088
# Silueta: 0.19099969974390538
# Silueta: 0.2573761920667403
#
#
# cluster con 212 segmentos
# Inercia: 95.52549983080694
# Silueta: 0.18559813487497331
# Silueta: 0.23627525076050757
#
#
# cluster con 213 segmentos
# Inercia: 93.61213714391641
# Silueta: 0.18627319212755422
# Silueta: 0.23950841275486331
#
#
# cluster con 214 segmentos
# Inercia: 91.94939352778
# Silueta: 0.18665645763434274
# Silueta: 0.24103852347174778
#
#
# cluster con 215 segmentos
# Inercia: 92.17706986730016
# Silueta: 0.183539199241318
# Silueta: 0.24159571264233823
#
#
# cluster con 216 segmentos
# Inercia: 91.03644567818543
# Silueta: 0.1831100078973443
# Silueta: 0.22340102539314194
#
#
# cluster con 217 segmentos
# Inercia: 90.35782095276718
# Silueta: 0.18223729574056058
# Silueta: 0.23795776564834306
#
#
# cluster con 218 segmentos
# Inercia: 89.04458443802315
# Silueta: 0.19044613263252996
# Silueta: 0.2548021628278857
#
#
# cluster con 219 segmentos
# Inercia: 87.50672695543028
# Silueta: 0.1843049808407069
# Silueta: 0.24261495600701294
#
#
# cluster con 220 segmentos
# Inercia: 86.26062610072194
# Silueta: 0.18108162629875232
# Silueta: 0.2277879958731027
#
#
# cluster con 221 segmentos
# Inercia: 85.23459589081511
# Silueta: 0.18621583900765648
# Silueta: 0.24877673931580196
#
#
# cluster con 222 segmentos
# Inercia: 86.9498276354338
# Silueta: 0.17842614744916563
# Silueta: 0.219578536948448
#
#
# cluster con 223 segmentos
# Inercia: 84.4915885210253
# Silueta: 0.17685212154806396
# Silueta: 0.22440727816083045
#
#
# cluster con 224 segmentos
# Inercia: 83.40810074956767
# Silueta: 0.1755148489514747
# Silueta: 0.23278211407491872
#
#
# cluster con 225 segmentos
# Inercia: 81.25670913339226
# Silueta: 0.18367750191563625
# Silueta: 0.22608527185396254
#
#
# cluster con 226 segmentos
# Inercia: 81.39034298082964
# Silueta: 0.185266481599644
# Silueta: 0.22797351885730693
#
#
# cluster con 227 segmentos
# Inercia: 79.3736681223106
# Silueta: 0.18415016579863164
# Silueta: 0.23911109854066598
#
#
# cluster con 228 segmentos
# Inercia: 79.47791223132546
# Silueta: 0.1792776850464181
# Silueta: 0.23958395124623075
#
#
# cluster con 229 segmentos
# Inercia: 77.57610882178544
# Silueta: 0.173670949188516
# Silueta: 0.21880451692795594
#
#
# cluster con 230 segmentos
# Inercia: 76.8529088158746
# Silueta: 0.17587038888634052
# Silueta: 0.2334214417131498
#
#
# cluster con 231 segmentos
# Inercia: 75.30435771586235
# Silueta: 0.18782787794621578
# Silueta: 0.2635274140766937
#
#
# cluster con 232 segmentos
# Inercia: 75.03603248350203
# Silueta: 0.18015023267961416
# Silueta: 0.22946408453226982
#
#
# cluster con 233 segmentos
# Inercia: 73.84258945235922
# Silueta: 0.1765494816345507
# Silueta: 0.23714580537195887
#
#
# cluster con 234 segmentos
# Inercia: 72.98559898948693
# Silueta: 0.17399292882297343
# Silueta: 0.23199041214437094
#
#
# cluster con 235 segmentos
# Inercia: 71.92678714467583
# Silueta: 0.17479269138698258
# Silueta: 0.23511620979662345
#
#
# cluster con 236 segmentos
# Inercia: 70.28070187467507
# Silueta: 0.17792927428831457
# Silueta: 0.23679031314891327
#
#
# cluster con 237 segmentos
# Inercia: 71.51585325881314
# Silueta: 0.1751540796301543
# Silueta: 0.23418285848694861
#
#
# cluster con 238 segmentos
# Inercia: 68.7096444439653
# Silueta: 0.17299901393979128
# Silueta: 0.23028978666217892
#
#
# cluster con 239 segmentos
# Inercia: 68.22823284137058
# Silueta: 0.17359815085527383
# Silueta: 0.21629367878099953
#
#
# cluster con 240 segmentos
# Inercia: 67.25959358434326
# Silueta: 0.17478610726334115
# Silueta: 0.24394221955423528
#
#
# cluster con 241 segmentos
# Inercia: 66.5476685219553
# Silueta: 0.1757846433467668
# Silueta: 0.23605819363304195
#
#
# cluster con 242 segmentos
# Inercia: 65.77097226673376
# Silueta: 0.17604228081604376
# Silueta: 0.22224191432449222
#
#
# cluster con 243 segmentos
# Inercia: 65.70070097428696
# Silueta: 0.16758295012727192
# Silueta: 0.21076700211375116
#
#
# cluster con 244 segmentos
# Inercia: 64.9512413833465
# Silueta: 0.1663744249709538
# Silueta: 0.2160045876551994
#
#
# cluster con 245 segmentos
# Inercia: 62.66011825448394
# Silueta: 0.1746855399702051
# Silueta: 0.23057923667321334
#
#
# cluster con 246 segmentos
# Inercia: 62.874836466772365
# Silueta: 0.16476971935448562
# Silueta: 0.2196811067977792
#
#
# cluster con 247 segmentos
# Inercia: 59.80292472659859
# Silueta: 0.17585474389536002
# Silueta: 0.2400940212075216
#
#
# cluster con 248 segmentos
# Inercia: 61.4030259178335
# Silueta: 0.16293559338359798
# Silueta: 0.2170542552864767
#
#
# cluster con 249 segmentos
# Inercia: 60.2295819329147
# Silueta: 0.16852030251631056
# Silueta: 0.23351062522869764
#
#
# cluster con 250 segmentos
# Inercia: 59.5030884649
# Silueta: 0.16740719956039274
# Silueta: 0.22134136021930378
#
#
# cluster con 251 segmentos
# Inercia: 57.14845256010155
# Silueta: 0.17385484661192738
# Silueta: 0.23774703721548843
#
#
# cluster con 252 segmentos
# Inercia: 57.630318753732666
# Silueta: 0.16900995173200958
# Silueta: 0.23149338922497897
#
#
# cluster con 253 segmentos
# Inercia: 55.26815477259757
# Silueta: 0.16983673030711965
# Silueta: 0.23832340888881118
#
#
# cluster con 254 segmentos
# Inercia: 55.95991838469858
# Silueta: 0.16433574461338304
# Silueta: 0.21575667106520754
#
#
# cluster con 255 segmentos
# Inercia: 54.5961010960046
# Silueta: 0.16867427711180308
# Silueta: 0.22291547178917603
#
#
# cluster con 256 segmentos
# Inercia: 53.98509930787767
# Silueta: 0.1675292253424805
# Silueta: 0.23050165984873008
#
#
# cluster con 257 segmentos
# Inercia: 53.82606549081791
# Silueta: 0.1681321891130308
# Silueta: 0.22532817959522788
#
#
# cluster con 258 segmentos
# Inercia: 52.11821918610571
# Silueta: 0.16600066931787386
# Silueta: 0.22731006747026983
#
#
# cluster con 259 segmentos
# Inercia: 52.224311293138356
# Silueta: 0.17002716139967894
# Silueta: 0.22843046987551152
#
#
# cluster con 260 segmentos
# Inercia: 50.815427962971
# Silueta: 0.15882066128262895
# Silueta: 0.2113456734642271
#
#
# cluster con 261 segmentos
# Inercia: 49.7481581293512
# Silueta: 0.16716660287376023
# Silueta: 0.22835855732809243
#
#
# cluster con 262 segmentos
# Inercia: 49.99548666928906
# Silueta: 0.16237277864033903
# Silueta: 0.21556073251952698
#
#
# cluster con 263 segmentos
# Inercia: 48.602020343558266
# Silueta: 0.16735322167581865
# Silueta: 0.2244033084926771
#
#
# cluster con 264 segmentos
# Inercia: 48.64105985173278
# Silueta: 0.1606688338285044
# Silueta: 0.21168662353251355
#
#
# cluster con 265 segmentos
# Inercia: 47.0897560124877
# Silueta: 0.16338511288605923
# Silueta: 0.22265677224005057
#
#
# cluster con 266 segmentos
# Inercia: 46.660180385187445
# Silueta: 0.1660204678333755
# Silueta: 0.22471094508432915
#
#
# cluster con 267 segmentos
# Inercia: 46.82037426891808
# Silueta: 0.15708707459803156
# Silueta: 0.20988121212589925
#
#
# cluster con 268 segmentos
# Inercia: 45.326774457982
# Silueta: 0.15912336243969954
# Silueta: 0.2144654342729101
#
#
# cluster con 269 segmentos
# Inercia: 45.484198046287894
# Silueta: 0.15934446816540912
# Silueta: 0.21187678756500797
#
#
# cluster con 270 segmentos
# Inercia: 44.02869183650762
# Silueta: 0.16460322911789585
# Silueta: 0.22402732533857758
#
#
# cluster con 271 segmentos
# Inercia: 43.921497382025095
# Silueta: 0.1567582493796342
# Silueta: 0.21117149816177486
#
#
# cluster con 272 segmentos
# Inercia: 43.29418102420097
# Silueta: 0.15723245097388558
# Silueta: 0.2047502659280552
#
#
# cluster con 273 segmentos
# Inercia: 42.50851421592699
# Silueta: 0.16221967260193834
# Silueta: 0.21682671234170908
#
#
# cluster con 274 segmentos
# Inercia: 41.50473057966529
# Silueta: 0.1583501910201243
# Silueta: 0.21232243307200863
#
#
# cluster con 275 segmentos
# Inercia: 40.24615509419064
# Silueta: 0.16129892880219435
# Silueta: 0.21972166622177736
#
#
# cluster con 276 segmentos
# Inercia: 39.95717373122484
# Silueta: 0.15724868685602614
# Silueta: 0.20979105133917486
#
#
# cluster con 277 segmentos
# Inercia: 39.790019751013226
# Silueta: 0.1560825297109148
# Silueta: 0.21142192806190127
#
#
# cluster con 278 segmentos
# Inercia: 38.55423199931056
# Silueta: 0.15745069733952077
# Silueta: 0.21212016586011187
#
#
# cluster con 279 segmentos
# Inercia: 38.757550959519854
# Silueta: 0.1529279612917146
# Silueta: 0.21475099994658836
#
#
# cluster con 280 segmentos
# Inercia: 37.67134432580657
# Silueta: 0.15632223953465907
# Silueta: 0.21269956886395716
#
#
# cluster con 281 segmentos
# Inercia: 37.879465004657455
# Silueta: 0.15270991523061503
# Silueta: 0.20979747630606435
#
#
# cluster con 282 segmentos
# Inercia: 36.90864393753686
# Silueta: 0.1488332250613215
# Silueta: 0.20113784464556492
#
#
# cluster con 283 segmentos
# Inercia: 36.45203955095221
# Silueta: 0.14518152352108998
# Silueta: 0.19965950844899205
#
#
# cluster con 284 segmentos
# Inercia: 35.9339975012862
# Silueta: 0.1545343669355181
# Silueta: 0.21309820333178886
#
#
# cluster con 285 segmentos
# Inercia: 35.27493127575333
# Silueta: 0.14748687490579995
# Silueta: 0.19667714335468284
#
#
# cluster con 286 segmentos
# Inercia: 34.439094332315804
# Silueta: 0.15045320160914313
# Silueta: 0.20348811296143587
#
#
# cluster con 287 segmentos
# Inercia: 33.93841683510947
# Silueta: 0.1481864567247864
# Silueta: 0.19784282225791466
#
#
# cluster con 288 segmentos
# Inercia: 33.397552531271494
# Silueta: 0.15129362500338875
# Silueta: 0.2090278799533505
#
#
# cluster con 289 segmentos
# Inercia: 33.157730629195115
# Silueta: 0.14525370008736452
# Silueta: 0.19791791972221676
#
#
# cluster con 290 segmentos
# Inercia: 33.067909980481836
# Silueta: 0.14265178176159268
# Silueta: 0.19056742032652538
#
#
# cluster con 291 segmentos
# Inercia: 31.934444252632332
# Silueta: 0.1432387839878731
# Silueta: 0.1924892683781271
#
#
# cluster con 292 segmentos
# Inercia: 30.996610193708865
# Silueta: 0.15025955071690195
# Silueta: 0.20317457848110676
#
#
# cluster con 293 segmentos
# Inercia: 30.910175726341414
# Silueta: 0.14434591208481487
# Silueta: 0.20148179594502527
#
#
# cluster con 294 segmentos
# Inercia: 30.165171442037867
# Silueta: 0.14742290384501383
# Silueta: 0.2054106204538386
#
#
# cluster con 295 segmentos
# Inercia: 29.404439933788474
# Silueta: 0.14482834612359277
# Silueta: 0.19781056391614288
#
#
# cluster con 296 segmentos
# Inercia: 29.542493524064923
# Silueta: 0.14626811169793333
# Silueta: 0.19633931721757378
#
#
# cluster con 297 segmentos
# Inercia: 29.003108424307978
# Silueta: 0.13828479348146452
# Silueta: 0.1905018875337072
#
#
# cluster con 298 segmentos
# Inercia: 28.188582421462176
# Silueta: 0.14718186965460947
# Silueta: 0.20293477225894765
#
#
# cluster con 299 segmentos
# Inercia: 27.899394510938755
# Silueta: 0.14247866501612289
# Silueta: 0.20182080225414076
#
#
# cluster con 300 segmentos
# Inercia: 27.519899099631296
# Silueta: 0.13817829554890518
# Silueta: 0.19469766092283336
#
#
# cluster con 301 segmentos
# Inercia: 26.96163446641482
# Silueta: 0.1449555808573352
# Silueta: 0.20199836377170652
#
#
# cluster con 302 segmentos
# Inercia: 26.025783181901296
# Silueta: 0.14042518672319815
# Silueta: 0.19147764812438087
#
#
# cluster con 303 segmentos
# Inercia: 26.098084789202417
# Silueta: 0.13953840395106876
# Silueta: 0.19382826651997348
#
#
# cluster con 304 segmentos
# Inercia: 25.472686719532305
# Silueta: 0.13628352537251684
# Silueta: 0.18948320300275132
#
#
# cluster con 305 segmentos
# Inercia: 24.892093112027005
# Silueta: 0.13496265146817302
# Silueta: 0.1905194166444955
#
#
# cluster con 306 segmentos
# Inercia: 24.478371315270323
# Silueta: 0.13521756380881061
# Silueta: 0.18887804730289348
#
#
# cluster con 307 segmentos
# Inercia: 24.25000416870737
# Silueta: 0.1288559800471439
# Silueta: 0.17742731578990376
#
#
# cluster con 308 segmentos
# Inercia: 23.627285131914917
# Silueta: 0.13395614133626974
# Silueta: 0.18532269230733478
#
#
# cluster con 309 segmentos
# Inercia: 23.167437792906167
# Silueta: 0.13271608837896934
# Silueta: 0.18242937757993918
#
#
# cluster con 310 segmentos
# Inercia: 23.089456802463914
# Silueta: 0.12741017515163006
# Silueta: 0.17637829935859095
#
#
# cluster con 311 segmentos
# Inercia: 22.219515006652994
# Silueta: 0.12278695725557998
# Silueta: 0.16785512201847702
#
#
# cluster con 312 segmentos
# Inercia: 22.02896235951424
# Silueta: 0.12919877141409047
# Silueta: 0.1811301859344444
#
#
# cluster con 313 segmentos
# Inercia: 21.099818670635276
# Silueta: 0.1285553387836531
# Silueta: 0.1848535233228094
#
#
# cluster con 314 segmentos
# Inercia: 20.87037137164586
# Silueta: 0.1257119118434147
# Silueta: 0.17743202981087558
#
#
# cluster con 315 segmentos
# Inercia: 20.62444922652562
# Silueta: 0.12494987556545437
# Silueta: 0.17396045893027984
#
#
# cluster con 316 segmentos
# Inercia: 19.697347997304036
# Silueta: 0.12618282691775953
# Silueta: 0.17791811642359584
#
#
# cluster con 317 segmentos
# Inercia: 19.44573145658688
# Silueta: 0.1292356458918982
# Silueta: 0.1816130726802421
#
#
# cluster con 318 segmentos
# Inercia: 19.50986028787156
# Silueta: 0.1294069534227157
# Silueta: 0.18011055215805102
#
#
# cluster con 319 segmentos
# Inercia: 18.963207053126432
# Silueta: 0.1257841116359707
# Silueta: 0.17691445745010237
#
#
# cluster con 320 segmentos
# Inercia: 18.714242678823055
# Silueta: 0.12405820612818169
# Silueta: 0.17460935812000006
#
#
# cluster con 321 segmentos
# Inercia: 18.02829774105665
# Silueta: 0.12348285744228489
# Silueta: 0.17874392255306967
#
#
# cluster con 322 segmentos
# Inercia: 17.426840500821775
# Silueta: 0.12054566447180981
# Silueta: 0.16967522897053547
#
#
# cluster con 323 segmentos
# Inercia: 17.322780748163723
# Silueta: 0.11903468122404837
# Silueta: 0.17450248830393364
#
#
# cluster con 324 segmentos
# Inercia: 16.952743771699364
# Silueta: 0.11409552654755693
# Silueta: 0.15821651235234568
#
#
# cluster con 325 segmentos
# Inercia: 16.283413781964065
# Silueta: 0.12240070891685562
# Silueta: 0.17560125859732695
#
#
# cluster con 326 segmentos
# Inercia: 16.13870411462264
# Silueta: 0.12103733470679875
# Silueta: 0.1713284394667444
#
#
# cluster con 327 segmentos
# Inercia: 15.823464373840856
# Silueta: 0.1263303891715208
# Silueta: 0.17974512196682227
#
#
# cluster con 328 segmentos
# Inercia: 15.744294175570275
# Silueta: 0.11898395123957416
# Silueta: 0.16693648614655412
#
#
# cluster con 329 segmentos
# Inercia: 14.970499818035641
# Silueta: 0.11848969827545018
# Silueta: 0.1706854727317445
#
#
# cluster con 330 segmentos
# Inercia: 14.892914758880899
# Silueta: 0.11407484823082802
# Silueta: 0.16111257639861584
#
#
# cluster con 331 segmentos
# Inercia: 14.353378831632456
# Silueta: 0.10881183498576583
# Silueta: 0.15929526481277145
#
#
# cluster con 332 segmentos
# Inercia: 14.356108709208897
# Silueta: 0.11419994477767163
# Silueta: 0.16495902485885452
#
#
# cluster con 333 segmentos
# Inercia: 13.424947211684238
# Silueta: 0.11592006667986612
# Silueta: 0.16705411694634442
#
#
# cluster con 334 segmentos
# Inercia: 13.141187954133628
# Silueta: 0.11844162237160324
# Silueta: 0.1705112333745344
#
#
# cluster con 335 segmentos
# Inercia: 12.91764787771115
# Silueta: 0.11702195206565642
# Silueta: 0.17082390227808392
#
#
# cluster con 336 segmentos
# Inercia: 12.496939200624848
# Silueta: 0.10986739133728603
# Silueta: 0.15864133542492814
#
#
# cluster con 337 segmentos
# Inercia: 12.026205793289066
# Silueta: 0.11266006097167892
# Silueta: 0.16195068348007974
#
#
# cluster con 338 segmentos
# Inercia: 11.777275199724766
# Silueta: 0.11121830017590581
# Silueta: 0.162534331076997
#
#
# cluster con 339 segmentos
# Inercia: 11.623101306810192
# Silueta: 0.11165900002979819
# Silueta: 0.16094085840039968
#
#
# cluster con 340 segmentos
# Inercia: 11.218281456288741
# Silueta: 0.10927019433055546
# Silueta: 0.16036875377408216
#
#
# cluster con 341 segmentos
# Inercia: 10.717991052848095
# Silueta: 0.11195989888622529
# Silueta: 0.1612103084245928
#
#
# cluster con 342 segmentos
# Inercia: 10.573124845846877
# Silueta: 0.10619989789352387
# Silueta: 0.15618037730859205
#
#
# cluster con 343 segmentos
# Inercia: 10.323766316249595
# Silueta: 0.10705881222778692
# Silueta: 0.1598628006321604
#
#
# cluster con 344 segmentos
# Inercia: 10.0892186344362
# Silueta: 0.10514311659754942
# Silueta: 0.15080112400061763
#
#
# cluster con 345 segmentos
# Inercia: 9.553621962295571
# Silueta: 0.10906119202023483
# Silueta: 0.15774119241736936
#
#
# cluster con 346 segmentos
# Inercia: 9.701325613817737
# Silueta: 0.1015704105678218
# Silueta: 0.14742702166558094
#
#
# cluster con 347 segmentos
# Inercia: 9.142013251159293
# Silueta: 0.10325001541548998
# Silueta: 0.1485457735083071
#
#
# cluster con 348 segmentos
# Inercia: 8.91362697433389
# Silueta: 0.10472694820979601
# Silueta: 0.1506830652696444
#
#
# cluster con 349 segmentos
# Inercia: 8.738056860616085
# Silueta: 0.10126168182778532
# Silueta: 0.1441888360484448
#
#
# cluster con 350 segmentos
# Inercia: 8.3880920392462
# Silueta: 0.10095170258733109
# Silueta: 0.1426479466221862
#
#
# cluster con 351 segmentos
# Inercia: 8.073617898398355
# Silueta: 0.09961688251751305
# Silueta: 0.1484644044511585
#
#
# cluster con 352 segmentos
# Inercia: 7.937723751937842
# Silueta: 0.0983101859273366
# Silueta: 0.13899006852477824
#
#
# cluster con 353 segmentos
# Inercia: 7.755801812346753
# Silueta: 0.095585682387198
# Silueta: 0.13772841983074502
#
#
# cluster con 354 segmentos
# Inercia: 7.572021176027406
# Silueta: 0.09860863211398295
# Silueta: 0.14113378317880604
#
#
# cluster con 355 segmentos
# Inercia: 7.16057346082344
# Silueta: 0.09698183103747264
# Silueta: 0.13879373701848025
#
#
# cluster con 356 segmentos
# Inercia: 6.9941622068904525
# Silueta: 0.09444526216827477
# Silueta: 0.13354736996037767
#
#
# cluster con 357 segmentos
# Inercia: 6.747417282337924
# Silueta: 0.0944626962616886
# Silueta: 0.1368635835546059
#
#
# cluster con 358 segmentos
# Inercia: 6.494121899544922
# Silueta: 0.09258942064310346
# Silueta: 0.13541534674046318
#
#
# cluster con 359 segmentos
# Inercia: 6.179867449823338
# Silueta: 0.09476439050249201
# Silueta: 0.13562166156380517
#
#
# cluster con 360 segmentos
# Inercia: 6.064951888800796
# Silueta: 0.08990924080931492
# Silueta: 0.1279260379196011
#
#
# cluster con 361 segmentos
# Inercia: 5.894519574758137
# Silueta: 0.0895947652905381
# Silueta: 0.12790650590142658
#
#
# cluster con 362 segmentos
# Inercia: 5.66518834661435
# Silueta: 0.0853930281461017
# Silueta: 0.12184393889408628
#
#
# cluster con 363 segmentos
# Inercia: 5.443709508265087
# Silueta: 0.08360877760421707
# Silueta: 0.11873459887656655
#
#
# cluster con 364 segmentos
# Inercia: 5.086146434002423
# Silueta: 0.0849222956061549
# Silueta: 0.12130973655137801
#
#
# cluster con 365 segmentos
# Inercia: 4.95838216237609
# Silueta: 0.08276725465137405
# Silueta: 0.11866239664256678
#
#
# cluster con 366 segmentos
# Inercia: 4.842030342601471
# Silueta: 0.08189797379741086
# Silueta: 0.117987891790319
#
#
# cluster con 367 segmentos
# Inercia: 4.497668458982254
# Silueta: 0.08358038852992834
# Silueta: 0.1207153951122071
#
#
# cluster con 368 segmentos
# Inercia: 4.364825673558148
# Silueta: 0.07969038275063776
# Silueta: 0.11486934845167682
#
#
# cluster con 369 segmentos
# Inercia: 4.192078434261555
# Silueta: 0.07951157061814418
# Silueta: 0.1158712402029589
#
#
# cluster con 370 segmentos
# Inercia: 4.158879892942984
# Silueta: 0.07459979346225903
# Silueta: 0.10726540322236106
#
#
# cluster con 371 segmentos
# Inercia: 3.851582436239464
# Silueta: 0.07284433071375551
# Silueta: 0.10429646672314208
#
#
# cluster con 372 segmentos
# Inercia: 3.7255682113483326
# Silueta: 0.07287904596087844
# Silueta: 0.10456968166248605
#
#
# cluster con 373 segmentos
# Inercia: 3.46256287541516
# Silueta: 0.07441403816763578
# Silueta: 0.10564468322486278
#
#
# cluster con 374 segmentos
# Inercia: 3.3334572653346797
# Silueta: 0.0669302941892477
# Silueta: 0.09768230292407308
#
#
# cluster con 375 segmentos
# Inercia: 3.1323618267784434
# Silueta: 0.067786544720455
# Silueta: 0.09682080649052034
#
#
# cluster con 376 segmentos
# Inercia: 2.947865780949869
# Silueta: 0.06746985038526943
# Silueta: 0.09634208023275742
#
#
# cluster con 377 segmentos
# Inercia: 2.857536749069739
# Silueta: 0.06225608664298491
# Silueta: 0.09000172339187486
#
#
# cluster con 378 segmentos
# Inercia: 2.63104000455394
# Silueta: 0.06413729072061417
# Silueta: 0.09099405229355216
#
#
# cluster con 379 segmentos
# Inercia: 2.4473217471823503
# Silueta: 0.06325620904760518
# Silueta: 0.09095778936192735
#
#
# cluster con 380 segmentos
# Inercia: 2.3105642640061452
# Silueta: 0.05947858439351062
# Silueta: 0.08587583033524249
#
#
# cluster con 381 segmentos
# Inercia: 2.1860293079301876
# Silueta: 0.05840080526921924
# Silueta: 0.0845020339808987
#
#
# cluster con 382 segmentos
# Inercia: 2.0344213093881844
# Silueta: 0.05666600719607097
# Silueta: 0.08094657159532777
#
#
# cluster con 383 segmentos
# Inercia: 1.9028138844911444
# Silueta: 0.055741757172718225
# Silueta: 0.07944142025920688
#
#
# cluster con 384 segmentos
# Inercia: 1.7662872003390997
# Silueta: 0.055985784425660726
# Silueta: 0.07982931107261972
#
#
# cluster con 385 segmentos
# Inercia: 1.6278038921257398
# Silueta: 0.054673874900231935
# Silueta: 0.07715186987799559
#
#
# cluster con 386 segmentos
# Inercia: 1.5026900754595551
# Silueta: 0.0530635623211732
# Silueta: 0.07432781176667329
#
#
# cluster con 387 segmentos
# Inercia: 1.3845615804231555
# Silueta: 0.05067130485988496
# Silueta: 0.06894635733762249
#
#
# cluster con 388 segmentos
# Inercia: 1.3006103216985925
# Silueta: 0.050920830974060555
# Silueta: 0.0712409566897751
#
#
# cluster con 389 segmentos
# Inercia: 1.1814552034296917
# Silueta: 0.049081076949738865
# Silueta: 0.06724553577218056
#
#
# cluster con 390 segmentos
# Inercia: 1.0442130747036473
# Silueta: 0.04839420794625617
# Silueta: 0.06562478517960327
#
#
# cluster con 391 segmentos
# Inercia: 0.9532647518787116
# Silueta: 0.04570711991129001
# Silueta: 0.0627332701952015
#
#
# cluster con 392 segmentos
# Inercia: 0.8612537927245005
# Silueta: 0.04545450736663215
# Silueta: 0.06250447430081282
#
#
# cluster con 393 segmentos
# Inercia: 0.7708574858147135
# Silueta: 0.04386104297707505
# Silueta: 0.06000480394168429
#
#
# cluster con 394 segmentos
# Inercia: 0.6952302748256364
# Silueta: 0.04246632199368242
# Silueta: 0.05683096485533176
#
#
# cluster con 395 segmentos
# Inercia: 0.6130802551684804
# Silueta: 0.04002447598456237
# Silueta: 0.05426830872388099
#
#
# cluster con 396 segmentos
# Inercia: 0.5342081580564018
# Silueta: 0.03911598655736976
# Silueta: 0.05188037550215781
#
#
# cluster con 397 segmentos
# Inercia: 0.46267047395201033
# Silueta: 0.037490912228728565
# Silueta: 0.04880835441588177
#
#
# cluster con 398 segmentos
# Inercia: 0.40383966198526255
# Silueta: 0.03645316690408969
# Silueta: 0.04787341351522495
#
#
# cluster con 399 segmentos
# Inercia: 0.33694942932434835
# Silueta: 0.03599206282227071
# Silueta: 0.04746193159473137

# %%
# Número optimo de clusters
kmeans = KMeans(n_clusters=)
kmeans.fit(X)
cluster = kmeans.predict(X)

# Graficamos nuestro cluster
fig = plt.figure()
f1 = data['AnnualIncome'].values
f2 = data['SpendingScore'].values

colores=['red','green','blue','cyan','yellow']
asignar=[]
for row in cluster:
    asignar.append(colores[row])
    
plt.scatter(f1, f2, c=asignar, s=20)
plt.show()

# %% [markdown]
# **Segmentación Jerárquica**

# %%
# Cargamos las librerias necesarias
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
# Creamos el dendograma para encontrar el número óptimo de clusters
plt.figure(figsize=(100,100))
dendrogram = sch.dendrogram(sch.linkage(X, method = 'ward'))
plt.xlabel('Muestras')
plt.ylabel('Distancias Euclidianas')
plt.title('Dendograma')
plt.show()
