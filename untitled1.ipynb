# %% [markdown]
# <a href="https://colab.research.google.com/github/roxyconstantine-dev/Proyecto-Final-de-An-lisis-Datos/blob/main/untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Proyecto final de Posgrado de Analisis de Datos con Python
#
# En el siguente proyecto se realiza en analisis de datos concretos de muestras de laboratorio de la industria minera realizados por el CIMPPIN.

# %%
import pandas as pd
import numpy as np

from sklearn.decomposition import FactorAnalysis, PCA
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import train_test_split, RandomizedSearchCV, learning_curve

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
import math
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import uniform
import statistics as stats





   # print(data.iloc[i]['first_name'])
   #for column in [data.isnull().any(axis=1)==True] : #Recorrer las columnas e interactura solo sobre las que tiene elementos nulos
     
    # for index in range(df.shape[1]):
    
     #   return lista

# %%
import pandas as pd
url="https://github.com/roxyconstantine-dev/Proyecto-Final-de-An-lisis-Datos/blob/main/ParaRosana.xlsx?raw=true"
datos=pd.read_excel(url)
#datos=datos.drop("Frente:")
datos
# Out:
#        Ni     Co     Fe   SiO2   MgO  Al2O3  Cr2O3    Mn    Cu    Zn    Na  \
# 0    1.23  0.130  42.01   8.46  2.98   4.85   2.00  1.00  0.02  0.03  0.21
# 1    0.93  0.050  41.59   4.05  0.52   6.05   1.46  0.36  0.02  0.02  0.22
# 2    1.10  0.070  44.80   5.87  0.40  14.41   1.35  0.55  0.02  0.02  0.22
# 3    1.14  0.080  43.96   5.12  0.96   8.09   1.25  0.57  0.02  0.02  0.22
# 4    1.11  0.090  43.98   4.85  0.40   9.99   1.30  0.64  0.02  0.02  0.15
# ..    ...    ...    ...    ...   ...    ...    ...   ...   ...   ...   ...
# 413  1.32  0.074  28.71  21.43  7.19   2.71   1.27  0.57   NaN   NaN   NaN
# 414  1.31  0.169  42.99   7.65  1.20   7.63   1.95  1.01   NaN   NaN   NaN
# 415  1.31  0.118  39.61  11.51  2.64   6.09   1.73  0.74   NaN   NaN   NaN
# 416  1.50  0.113  34.19  14.88  4.79   4.05   1.50  0.79   NaN   NaN   NaN
# 417  1.72  0.096  36.29  15.13  3.86   3.92   1.61  0.72   NaN   NaN   NaN
#
#         K
# 0    0.01
# 1    0.01
# 2    0.01
# 3    0.00
# 4    0.01
# ..    ...
# 413   NaN
# 414   NaN
# 415   NaN
# 416   NaN
# 417   NaN
#
# [418 rows x 12 columns]

# %% [markdown]
# Para conocer el numero de datos faltantes se ejecuta el siguiente codigo

# %%
datos.isnull().sum().sum()
# Out:
# 1115

# %% [markdown]
# Tenemos numerosos datos vacios.
# Calculemos los valores faltantes por columna.

# %%
datos2 = datos.fillna(0)
datos2
# Out:
#        Ni     Co     Fe   SiO2   MgO  Al2O3  Cr2O3    Mn    Cu    Zn    Na  \
# 0    1.23  0.130  42.01   8.46  2.98   4.85   2.00  1.00  0.02  0.03  0.21
# 1    0.93  0.050  41.59   4.05  0.52   6.05   1.46  0.36  0.02  0.02  0.22
# 2    1.10  0.070  44.80   5.87  0.40  14.41   1.35  0.55  0.02  0.02  0.22
# 3    1.14  0.080  43.96   5.12  0.96   8.09   1.25  0.57  0.02  0.02  0.22
# 4    1.11  0.090  43.98   4.85  0.40   9.99   1.30  0.64  0.02  0.02  0.15
# ..    ...    ...    ...    ...   ...    ...    ...   ...   ...   ...   ...
# 413  1.32  0.074  28.71  21.43  7.19   2.71   1.27  0.57  0.00  0.00  0.00
# 414  1.31  0.169  42.99   7.65  1.20   7.63   1.95  1.01  0.00  0.00  0.00
# 415  1.31  0.118  39.61  11.51  2.64   6.09   1.73  0.74  0.00  0.00  0.00
# 416  1.50  0.113  34.19  14.88  4.79   4.05   1.50  0.79  0.00  0.00  0.00
# 417  1.72  0.096  36.29  15.13  3.86   3.92   1.61  0.72  0.00  0.00  0.00
#
#         K
# 0    0.01
# 1    0.01
# 2    0.01
# 3    0.00
# 4    0.01
# ..    ...
# 413  0.00
# 414  0.00
# 415  0.00
# 416  0.00
# 417  0.00
#
# [418 rows x 12 columns]

# %% [markdown]
# Los valores de Cr2O3,Cu,Zn,Na,K exiben la mayor cantidad de valores nulos.Vamos a analizar su comportamiento para predecir ls valores de los que podrian tratarse esatas casillas nulas ya que eliminarlas nos haría perder mucha información.

# %%
datos2.describe()
# Out:
#                Ni          Co          Fe        SiO2         MgO       Al2O3  \
# count  415.000000  415.000000  415.000000  415.000000  415.000000  415.000000
# mean     1.070313    0.117369   39.878096    8.643422    3.472171    6.762892
# std      0.298055    0.057196    8.177749    7.235043    4.170702    2.404156
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.850000    0.080000   36.095000    3.455000    0.845000    5.220000
# 50%      1.050000    0.100000   42.260000    6.590000    1.750000    6.460000
# 75%      1.250000    0.150000   45.795000   11.115000    4.390000    8.070000
# max      2.000000    0.330000   50.300000   50.080000   21.960000   16.790000
#
#             Cr2O3          Mn          Cu          Zn          Na           K
# count  415.000000  415.000000  415.000000  415.000000  415.000000  415.000000
# mean     1.449277    0.743880    0.007229    0.014819    0.024723    0.000867
# std      1.101166    0.319524    0.009024    0.018029    0.042271    0.002818
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.550000    0.000000    0.000000    0.000000    0.000000
# 50%      1.590000    0.710000    0.000000    0.000000    0.000000    0.000000
# 75%      2.185000    0.880000    0.020000    0.030000    0.040000    0.000000
# max      4.710000    3.000000    0.040000    0.050000    0.220000    0.010000

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

datos2['Ni']=MinMaxScaler().fit_transform(np.array(datos2['Ni']).reshape(-1,1))
datos2['Fe']=MinMaxScaler().fit_transform(np.array(datos2['Fe']).reshape(-1,1))
datos2['SiO2']=MinMaxScaler().fit_transform(np.array(datos2['SiO2']).reshape(-1,1))
datos2['MgO']=MinMaxScaler().fit_transform(np.array(datos2['MgO']).reshape(-1,1))
datos2['Al2O3']=MinMaxScaler().fit_transform(np.array(datos2['Al2O3']).reshape(-1,1))
datos2['Cr2O3']=MinMaxScaler().fit_transform(np.array(datos2['Cr2O3']).reshape(-1,1))
datos2['MgO']=MinMaxScaler().fit_transform(np.array(datos2['MgO']).reshape(-1,1))
datos2['Mn']=MinMaxScaler().fit_transform(np.array(datos2['Mn']).reshape(-1,1))
datos2['Co']=MinMaxScaler().fit_transform(np.array(datos2['Co']).reshape(-1,1))
datos2['Cu']=MinMaxScaler().fit_transform(np.array(datos2['Cu']).reshape(-1,1))
datos2['K']=MinMaxScaler().fit_transform(np.array(datos2['K']).reshape(-1,1))
datos2['Na']=MinMaxScaler().fit_transform(np.array(datos2['Na']).reshape(-1,1))
datos2['Zn']=MinMaxScaler().fit_transform(np.array(datos2['Zn']).reshape(-1,1))

# %%
datos2.describe()
# Out:
#                Ni          Co          Fe        SiO2         MgO       Al2O3  \
# count  415.000000  415.000000  415.000000  415.000000  415.000000  415.000000
# mean     0.535157    0.355663    0.792805    0.172592    0.158113    0.402793
# std      0.149028    0.173322    0.162580    0.144470    0.189923    0.143190
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.425000    0.242424    0.717594    0.068990    0.038479    0.310899
# 50%      0.525000    0.303030    0.840159    0.131589    0.079690    0.384753
# 75%      0.625000    0.454545    0.910437    0.221945    0.199909    0.480643
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#             Cr2O3          Mn          Cu          Zn          Na           K
# count  415.000000  415.000000  415.000000  415.000000  415.000000  415.000000
# mean     0.307702    0.247960    0.180723    0.296386    0.112377    0.086747
# std      0.233793    0.106508    0.225601    0.360570    0.192140    0.281804
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.183333    0.000000    0.000000    0.000000    0.000000
# 50%      0.337580    0.236667    0.000000    0.000000    0.000000    0.000000
# 75%      0.463907    0.293333    0.500000    0.600000    0.181818    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000

# %%
#NORMALIZANDO llevando a media cero y varianza 1
from scipy.ndimage import standard_deviation
arreglo=datos2.to_numpy()

from sklearn.preprocessing import StandardScaler
X=StandardScaler().fit_transform(arreglo)

print(X)

#
# Out:
# [[ 0.53640912  0.22110353  0.26101031 ...  0.84305552  4.38839126
#    3.24465372]
#  [-0.47133097 -1.17927367  0.20958944 ...  0.28770943  4.62524682
#    3.24465372]
#  [ 0.09972175 -0.82917937  0.60259177 ...  0.28770943  4.62524682
#    3.24465372]
#  ...
#  [ 0.80513982  0.01104695 -0.03282321 ... -0.82298277 -0.58557542
#   -0.3081993 ]
#  [ 1.44337521 -0.07647662 -0.69639724 ... -0.82298277 -0.58557542
#   -0.3081993 ]
#  [ 2.18238461 -0.37405678 -0.43929291 ... -0.82298277 -0.58557542
#   -0.3081993 ]]

# %%
print(sum(X))
# Out:
# [-8.79296636e-14 -2.37032616e-14 -1.64701586e-13 -1.04805054e-13
#   7.14844850e-14 -8.10462808e-14 -3.00592884e-14 -3.86357613e-14
#   7.02327085e-13 -2.36033415e-13  2.30260255e-13  5.41788836e-13]

# %%
#Mostrando el grafioc de algunas muestras en funcion del Niquel que es el principal objeto de estudio
x=X[:,0]
y=X[:,1]
plt.figure(figsize=(15,10))
y1=X[:,2]
y2=X[:,3]
plt.plot(x, y,'.', label = "Niquel y Cobalto")
plt.plot(x, y1,'.', label = "Niquel y Hierro")
plt.plot(x, y2,'.', label = "Niquel y SiO2")
plt.legend(loc = "upper left")

# %%
#Mostrando el grafioc de algunas muestras en funcion del Niquel que es el principal objeto de estudio
x=X[:,0]
y=X[:,5]
plt.figure(figsize=(15,10))
y1=X[:,6]
y2=X[:,7]
plt.plot(x, y,'.', label = "Niquel y Oxido de Silicio",color="orange")
plt.plot(x, y1,'.', label = "Niquel y Oxido de Magnesio",color="red")
plt.plot(x, y2,'.', label = "Niquel y Oxido de Aluminio ",color="blue")
plt.legend(loc = "upper left")

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=4)
CP=pca.fit_transform(X)
print(CP)
# Out:
# [[ 2.61459437  2.52074645  1.49890299  3.18916161]
#  [ 2.05912931  2.34069722  3.86636956  1.99850796]
#  [ 3.00006432  1.39409184  4.60951562  3.48305082]
#  ...
#  [-1.1889416  -0.40961947 -0.71539394  0.34956541]
#  [-1.6981195   0.62207015 -1.52378796  0.36453163]
#  [-1.83190316  0.63338375 -1.54288288  0.55961881]]

# %%
# Out:
#         Ni        Co        Fe      SiO2       MgO     Al2O3     Cr2O3  \
# 0    0.615  0.393939  0.835189  0.168930  0.135701  0.288862  0.424628
# 1    0.465  0.151515  0.826839  0.080871  0.023679  0.360334  0.309979
# 2    0.550  0.212121  0.890656  0.117212  0.018215  0.858249  0.286624
# 3    0.570  0.242424  0.873956  0.102236  0.043716  0.481834  0.265393
# 4    0.555  0.272727  0.874354  0.096845  0.018215  0.594997  0.276008
# ..     ...       ...       ...       ...       ...       ...       ...
# 413  0.660  0.224242  0.570775  0.427915  0.327413  0.161406  0.269639
# 414  0.655  0.512121  0.854672  0.152756  0.054645  0.454437  0.414013
# 415  0.655  0.357576  0.787475  0.229832  0.120219  0.362716  0.367304
# 416  0.750  0.342424  0.679722  0.297125  0.218124  0.241215  0.318471
# 417  0.860  0.290909  0.721471  0.302117  0.175774  0.233472  0.341826
#
#            Mn   Cu   Zn        Na    K
# 0    0.333333  0.5  0.6  0.954545  1.0
# 1    0.120000  0.5  0.4  1.000000  1.0
# 2    0.183333  0.5  0.4  1.000000  1.0
# 3    0.190000  0.5  0.4  1.000000  0.0
# 4    0.213333  0.5  0.4  0.681818  1.0
# ..        ...  ...  ...       ...  ...
# 413  0.190000  0.0  0.0  0.000000  0.0
# 414  0.336667  0.0  0.0  0.000000  0.0
# 415  0.246667  0.0  0.0  0.000000  0.0
# 416  0.263333  0.0  0.0  0.000000  0.0
# 417  0.240000  0.0  0.0  0.000000  0.0
#
# [415 rows x 12 columns]

# %%
datos2.describe()
# Out:
#            Pilas:          Ni          Co          Fe        SiO2         MgO  \
# count  418.000000  418.000000  418.000000  418.000000  418.000000  418.000000
# mean   126.772727    0.534569    0.355648    0.793590    0.172095    0.157365
# std     89.538885    0.148677    0.172804    0.162306    0.144086    0.189490
# min      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     54.250000    0.425000    0.242424    0.718638    0.068840    0.038251
# 50%    112.000000    0.525000    0.303030    0.843141    0.131589    0.079235
# 75%    180.750000    0.625000    0.454545    0.910586    0.221745    0.199340
# max    338.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#             Al2O3       Cr2O3          Mn          Cu          Zn          Na  \
# count  418.000000  418.000000  418.000000  418.000000  418.000000  418.000000
# mean     0.403313    0.307744    0.247919    0.181818    0.297608    0.112440
# std      0.143107    0.234016    0.106208    0.226043    0.360713    0.191587
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.312537    0.000000    0.183333    0.000000    0.000000    0.000000
# 50%      0.385051    0.336518    0.235000    0.000000    0.000000    0.000000
# 75%      0.480643    0.465499    0.293333    0.500000    0.600000    0.181818
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                 K
# count  418.000000
# mean     0.086124
# std      0.280884
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000

# %% [markdown]
# plt.scatter(datos2["Ni"], datos2["Cr203"])
#
# plt.show()

# %%
datos3=datos2
dato4=datos3.drop(['Pilas:'],axis=1,)
dato4.plot(kind='bar',figsize=(15, 15))

# %%
dato4.corr()
# Out:
#              Ni        Co        Fe      SiO2       MgO     Al2O3     Cr2O3  \
# Ni     1.000000  0.082533 -0.152173  0.291091  0.254757 -0.291221  0.038742
# Co     0.082533  1.000000  0.349308 -0.306690 -0.229664  0.100410 -0.259732
# Fe    -0.152173  0.349308  1.000000 -0.648852 -0.657235  0.373409 -0.005993
# SiO2   0.291091 -0.306690 -0.648852  1.000000  0.699027 -0.387010 -0.081137
# MgO    0.254757 -0.229664 -0.657235  0.699027  1.000000 -0.456847 -0.199911
# Al2O3 -0.291221  0.100410  0.373409 -0.387010 -0.456847  1.000000  0.152909
# Cr2O3  0.038742 -0.259732 -0.005993 -0.081137 -0.199911  0.152909  1.000000
# Mn     0.144039  0.705005  0.292315 -0.252820 -0.229537  0.112019 -0.127658
# Cu    -0.034770  0.277728  0.211375 -0.092322 -0.033077  0.092209 -0.724459
# Zn     0.004944  0.333418  0.177082 -0.060471  0.045654  0.007254 -0.793755
# Na     0.020398 -0.043044 -0.093232  0.212074  0.065163  0.229565 -0.290747
# K      0.112580  0.023191 -0.158823  0.240970  0.132630  0.081623 -0.164608
#
#              Mn        Cu        Zn        Na         K
# Ni     0.144039 -0.034770  0.004944  0.020398  0.112580
# Co     0.705005  0.277728  0.333418 -0.043044  0.023191
# Fe     0.292315  0.211375  0.177082 -0.093232 -0.158823
# SiO2  -0.252820 -0.092322 -0.060471  0.212074  0.240970
# MgO   -0.229537 -0.033077  0.045654  0.065163  0.132630
# Al2O3  0.112019  0.092209  0.007254  0.229565  0.081623
# Cr2O3 -0.127658 -0.724459 -0.793755 -0.290747 -0.164608
# Mn     1.000000  0.105534  0.122954 -0.109610 -0.000140
# Cu     0.105534  1.000000  0.920031  0.552483  0.291000
# Zn     0.122954  0.920031  1.000000  0.488131  0.257661
# Na    -0.109610  0.552483  0.488131  1.000000  0.573131
# K     -0.000140  0.291000  0.257661  0.573131  1.000000

# %%
componentsDf = dato4.DataFrame(data = components, columns = ['Ni', 'Co','Fe'])
pcaDf = pd.concat([componentsDf, Y], axis=1)

plt.figure(figsize=(12, 6))
sns.scatterplot(data=pcaDf, x="PC1", y="PC2", hue="species")

# %%
dato4.plot(kind = 'scatter',x='Mn',y='Co',color='green')#El Magnecio y el cobalto tienen una correlacin de 0.70
dato4.plot(kind = 'scatter',x='Zn',y='Cu',color='blue')#El zinc y el cobre tienen una correlación del 0.920031
dato4.plot(kind = 'scatter',x='SiO2',y='MgO',color='purple')#El oxido de magnecio y eloxido de silicio
plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import scale

pca_pipe = make_pipeline(StandardScaler(), PCA())
pca_pipe.fit(dato4)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('pca', PCA())])

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 7))
modelo_pca = pca_pipe.named_steps['pca']
componentes = modelo_pca.components_
plt.imshow(componentes.T, cmap='viridis', aspect='auto')
plt.yticks(range(len(datos.columns)), datos.columns)
plt.xticks(range(len(datos.columns)), np.arange(modelo_pca.n_components_) + 1)
plt.grid(False)
plt.colorbar();

# %%
print('----------------------------------------------------')
print('Porcentaje de varianza explicada por cada componente')
print('----------------------------------------------------')
print(modelo_pca.explained_variance_ratio_)
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6, 4))
ax.bar(
x = np.arange(modelo_pca.n_components_) + 1,
height = modelo_pca.explained_variance_ratio_
)
for x, y in zip(np.arange(len(datos.columns)) + 1, modelo_pca.explained_variance_ratio_):label = round(y, 2)
ax.annotate(
label,
(x,y),
textcoords="offset points",
xytext=(0,10),
ha='center'
)
ax.set_xticks(np.arange(modelo_pca.n_components_) + 1)
ax.set_ylim(0, 1.1)
ax.set_title('Porcentaje de varianza explicada por cada componente')
ax.set_xlabel('Componentes principales')
ax.set_ylabel('Por. varianza explicada');
# Out:
# ----------------------------------------------------
# Porcentaje de varianza explicada por cada componente
# ----------------------------------------------------
# [0.27762245 0.25473331 0.13769159 0.10207568 0.06328559 0.04424758
#  0.02895432 0.027298   0.02407793 0.02006988 0.0144304  0.00551328]

# %%
df=dato4
scaler=StandardScaler()
scaler.fit(df) # calculo la media para poder hacer la transformacion
X_scaled=scaler.transform(df)# Ahora si, escalo los datos y los normalizo
scaler.fit(df) # calculo la media para poder hacer la transformacion
X_scaled=scaler.transform(df)# Ahora si, escalo los datos y los normalizo

# %%
#Instanciamos objeto PCA y aplicamos
pca=PCA(n_components=12) # Otra opción es instanciar pca sólo con dimensiones nuevas hasta obtener un mínimo "explicado" ej.: pca=PCA(.85)
pca.fit(X_scaled) # obtener los componentes principales
X_pca=pca.transform(X_scaled) # convertimos nuestros datos con las nuevas dimensiones de PCA
print("shape of X_pca", X_pca.shape)
expl = pca.explained_variance_ratio_
print(expl)
print('suma:',sum(expl[0:5]))
# Out:
# shape of X_pca (418, 12)
# [0.27762245 0.25473331 0.13769159 0.10207568 0.06328559 0.04424758
#  0.02895432 0.027298   0.02407793 0.02006988 0.0144304  0.00551328]
# suma: 0.8354086105343136

# %%
#graficamos el acumulado de varianza explicada en las nuevas dimensiones
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Número de componentes (dimensiones)')
plt.ylabel('Acumulación de la varianza')
plt.show()
