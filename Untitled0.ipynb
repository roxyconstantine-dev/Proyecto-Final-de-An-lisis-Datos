# %% [markdown]
# <a href="https://colab.research.google.com/github/roxyconstantine-dev/Proyecto-Final-de-An-lisis-Datos/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from sklearn.decomposition import FactorAnalysis, PCA
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import train_test_split, RandomizedSearchCV, learning_curve

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.cluster import KMeans
import math
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import uniform
import statistics as stats
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Chapter 4&5
from sklearn.decomposition import PCA

# Chapter 6
from sklearn.decomposition import IncrementalPCA

# Chapter 7
from sklearn.decomposition import KernelPCA
from sklearn.datasets import make_swiss_roll

from mpl_toolkits.mplot3d import Axes3D
#from pydiffmap import diffusion_map as dm
#from pydiffmap.visualization import data_plot

# Chapter 8
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

import pandas as pd
url="https://github.com/roxyconstantine-dev/Proyecto-Final-de-An-lisis-Datos/blob/main/ParaRosana.xlsx?raw=true"
datos=pd.read_excel(url)
url1="https://github.com/roxyconstantine-dev/Proyecto-Final-de-An-lisis-Datos/blob/main/ParaRosanaTrain.xlsx?raw=true"
test=pd.read_excel(url1)

# %%
datos
# Out:
#        Ni     Co     Fe   SiO2   MgO  Al2O3  Cr2O3    Mn    Cu    Zn    Na  \
# 0    1.23  0.130  42.01   8.46  2.98   4.85   2.00  1.00  0.02  0.03  0.21
# 1    0.93  0.050  41.59   4.05  0.52   6.05   1.46  0.36  0.02  0.02  0.22
# 2    1.10  0.070  44.80   5.87  0.40  14.41   1.35  0.55  0.02  0.02  0.22
# 3    1.14  0.080  43.96   5.12  0.96   8.09   1.25  0.57  0.02  0.02  0.22
# 4    1.11  0.090  43.98   4.85  0.40   9.99   1.30  0.64  0.02  0.02  0.15
# ..    ...    ...    ...    ...   ...    ...    ...   ...   ...   ...   ...
# 410  1.58  0.104  26.91  23.36  8.03   2.59   1.22  0.47   NaN   NaN   NaN
# 411  1.41  0.184  44.37   6.66  1.46   6.23   1.97  0.85   NaN   NaN   NaN
# 412  1.19  0.151  41.96   6.96  1.64   5.03   1.98  0.71   NaN   NaN   NaN
# 413  1.32  0.074  28.71  21.43  7.19   2.71   1.27  0.57   NaN   NaN   NaN
# 414  1.31  0.169  42.99   7.65  1.20   7.63   1.95  1.01   NaN   NaN   NaN
#
#         K Frente
# 0    0.01     YS
# 1    0.01     CE
# 2    0.01     CE
# 3    0.00     CE
# 4    0.01     CE
# ..    ...    ...
# 410   NaN     YS
# 411   NaN     CE
# 412   NaN     YS
# 413   NaN     YN
# 414   NaN     YN
#
# [415 rows x 13 columns]

# %%
datos = datos.dropna(how='all')
datos2 = datos.fillna(0)
datos2
# Out:
#        Ni     Co     Fe   SiO2   MgO  Al2O3  Cr2O3    Mn    Cu    Zn    Na  \
# 0    1.23  0.130  42.01   8.46  2.98   4.85   2.00  1.00  0.02  0.03  0.21
# 1    0.93  0.050  41.59   4.05  0.52   6.05   1.46  0.36  0.02  0.02  0.22
# 2    1.10  0.070  44.80   5.87  0.40  14.41   1.35  0.55  0.02  0.02  0.22
# 3    1.14  0.080  43.96   5.12  0.96   8.09   1.25  0.57  0.02  0.02  0.22
# 4    1.11  0.090  43.98   4.85  0.40   9.99   1.30  0.64  0.02  0.02  0.15
# ..    ...    ...    ...    ...   ...    ...    ...   ...   ...   ...   ...
# 410  1.58  0.104  26.91  23.36  8.03   2.59   1.22  0.47  0.00  0.00  0.00
# 411  1.41  0.184  44.37   6.66  1.46   6.23   1.97  0.85  0.00  0.00  0.00
# 412  1.19  0.151  41.96   6.96  1.64   5.03   1.98  0.71  0.00  0.00  0.00
# 413  1.32  0.074  28.71  21.43  7.19   2.71   1.27  0.57  0.00  0.00  0.00
# 414  1.31  0.169  42.99   7.65  1.20   7.63   1.95  1.01  0.00  0.00  0.00
#
#         K Frente
# 0    0.01     YS
# 1    0.01     CE
# 2    0.01     CE
# 3    0.00     CE
# 4    0.01     CE
# ..    ...    ...
# 410  0.00     YS
# 411  0.00     CE
# 412  0.00     YS
# 413  0.00     YN
# 414  0.00     YN
#
# [415 rows x 13 columns]

# %%
X = datos2.drop(['Frente'], axis=1)
 Y= datos2['Frente']
sc = StandardScaler()
X = X.values
X_std =  sc.fit_transform(X)  
cov_matrix = np.cov(X_std.T)
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

# %%
tot = sum(eigenvalues)
var_explained = [(i / tot) for i in sorted(eigenvalues, reverse=True)] 
cum_var_exp = np.cumsum(var_explained)

# %%
plt.bar(range(1,len(var_explained)+1), var_explained, alpha=0.5, align='center', label='individual explained variance')
plt.step(range(1,len(var_explained)+1),cum_var_exp, where= 'mid', label='cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal components')
plt.legend(loc = 'best')
plt.show()

# %%
pca = PCA(n_components = 5)
pca.fit(X_std)
x_pca = pca.transform(X_std)
pca.explained_variance_ratio_
# Out:
# array([0.27688031, 0.25526741, 0.13725174, 0.10240734, 0.06340652])

# %%
pca.explained_variance_ratio_.sum()
# Out:
# 0.8352133096367383

# %%
pca = PCA(n_components = 0.8)
pca.fit(X_std)
x_pca = pca.transform(X_std)
pca.n_components_
# Out:
# 5

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2).fit(X)
principal_comps = pca.transform(X)
pca_db = pd.DataFrame(data = principal_comps, columns=['pca1', 'pca2'])
pca_db
# Out:
#           pca1      pca2
# 0    -1.521931 -1.296168
# 1    -4.789316  2.539943
# 2    -6.905345 -0.635518
# 3    -5.921750  0.173972
# 4    -6.475358  0.498526
# ..         ...       ...
# 410  20.255519 -2.734180
# 411  -4.939243 -1.332011
# 412  -2.836982  0.008076
# 413  17.504558 -2.424343
# 414  -3.572730 -1.040227
#
# [415 rows x 2 columns]

# %%
# Adicionemos ahora la columna con la clase correcta
pca_db['class'] =Y
pca_db
# Out:
#           pca1      pca2 class
# 0    -1.521931 -1.296168    YS
# 1    -4.789316  2.539943    CE
# 2    -6.905345 -0.635518    CE
# 3    -5.921750  0.173972    CE
# 4    -6.475358  0.498526    CE
# ..         ...       ...   ...
# 410  20.255519 -2.734180    YS
# 411  -4.939243 -1.332011    CE
# 412  -2.836982  0.008076    YS
# 413  17.504558 -2.424343    YN
# 414  -3.572730 -1.040227    YN
#
# [415 rows x 3 columns]

# %%
# y visualicemos el resultado
fig, ax = plt.subplots(figsize=(15, 15))
scatter = ax.scatter(pca_db['pca1'], pca_db['pca2'], c=pca_db['class'], cmap="Spectral")
legend1 = ax.legend(*scatter.legend_elements(),
                    loc="upper right", title="Classes")
ax.add_artist(legend1)
ax.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4219             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4220                 colors = mcolors.to_rgba_array(c)
#    4221             except (TypeError, ValueError) as err:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     376     else:
# --> 377         rgba = np.array([to_rgba(cc) for cc in c])
#     378
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/colors.py in <listcomp>(.0)
#     376     else:
# --> 377         rgba = np.array([to_rgba(cc) for cc in c])
#     378
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     186     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 187         rgba = _to_rgba_no_colorcycle(c, alpha)
#     188         try:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     261             return c, c, c, alpha if alpha is not None else 1.
# --> 262         raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     263     # turn 2-D array into 1-D array
#
# ValueError: Invalid RGBA argument: 'YS'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-560c9c3f58b8> in <module>
#       1 # y visualicemos el resultado
#       2 fig, ax = plt.subplots(figsize=(15, 15))
# ----> 3 scatter = ax.scatter(pca_db['pca1'], pca_db['pca2'], c=pca_db['class'], cmap="Spectral")
#       4 legend1 = ax.legend(*scatter.legend_elements(),
#       5                     loc="upper right", title="Classes")
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1412     def inner(ax, *args, data=None, **kwargs):
#    1413         if data is None:
# -> 1414             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1415
#    1416         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4384             orig_edgecolor = kwargs.get('edgecolor', None)
#    4385         c, colors, edgecolors = \
# -> 4386             self._parse_scatter_color_args(
#    4387                 c, edgecolors, kwargs, x.size,
#    4388                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4227                     # Both the mapping *and* the RGBA conversion failed: pretty
#    4228                     # severe failure => one may appreciate a verbose feedback.
# -> 4229                     raise ValueError(
#    4230                         f"'c' argument must be a color, a sequence of colors, "
#    4231                         f"or a sequence of numbers, not {c}") from err
#
# ValueError: 'c' argument must be a color, a sequence of colors, or a sequence of numbers, not 0      YS
# 1      CE
# 2      CE
# 3      CE
# 4      CE
#        ..
# 410    YS
# 411    CE
# 412    YS
# 413    YN
# 414    YN
# Name: class, Length: 415, dtype: object

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train)
standardized_X = scaler.transform(X_train)
standardized_X_test = scaler.transform(X_test)

k_means.fit(X)
pca_model = pca.fit_transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-869d09a73199> in <module>
# ----> 1 k_means.fit(X)
#       2 pca_model = pca.fit_transform(X_train)
#
# NameError: name 'k_means' is not defined
